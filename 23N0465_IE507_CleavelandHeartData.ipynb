# %% [markdown]
# # **Lab 12**: Practice Code for advance data visualization
#
# By: \\
# *Prof. N. Hemachandra & R. Deval*
#
# **Objective**: In this practice code, students use combination of pandas and sklearn to visualize given data set.
#
# Link for [cleveland\_heart\_attr.csv](https://drive.google.com/file/d/1NPVC_y2Pw8fgH_fiQQRfcwpU-QWIuFGz/view?usp=sharing) \\
# Link for [cleveland\_heart\_attr\_description.txt](https://drive.google.com/file/d/1Zu7NibFCW3gx6PoFrbCSPxw-MaA67Vbf/view?usp=sharing)

# %% [markdown]
# 2.1.
# After loading the data into the pandas dataframe df, write code to identify the number of rows and
# columns that df has, and print them.

# %%
#importing pandas which will be heavly used throughout this session
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Please copy the 'cleveland_heart_attr.csv' and 'cleveland_heart_attr_description.txt' files to the current folder in colab
#read the csv file into a dataframe
df = pd.read_csv('cleveland_heart_attr.csv')

# %%
#check the data frame by printing its first (five) few rows
df.head()
# Out:
#     age  sex  chest_pain_type  rest_bp  serum_cholesterol  fastblood_sugar  \
# 0  63.0  1.0              1.0    145.0              233.0              1.0
# 1  67.0  1.0              4.0    160.0              286.0              0.0
# 2  67.0  1.0              4.0    120.0              229.0              0.0
# 3  37.0  1.0              3.0    130.0              250.0              0.0
# 4  41.0  0.0              2.0    130.0              204.0              0.0
#
#    rest_ecg  max_heartrate  exercise_angina  \
# 0       2.0          150.0              0.0
# 1       2.0          108.0              1.0
# 2       2.0          129.0              1.0
# 3       0.0          187.0              0.0
# 4       2.0          172.0              0.0
#
#    ST_depression_exercise_relativeto_rest  slope_peak_STsegment  \
# 0                                     2.3                   3.0
# 1                                     1.5                   2.0
# ...

# %%
#check the data frame by printing its last  (five) few rows
df
# Out:
#       age  sex  chest_pain_type  rest_bp  serum_cholesterol  fastblood_sugar  \
# 0    63.0  1.0              1.0    145.0              233.0              1.0
# 1    67.0  1.0              4.0    160.0              286.0              0.0
# 2    67.0  1.0              4.0    120.0              229.0              0.0
# 3    37.0  1.0              3.0    130.0              250.0              0.0
# 4    41.0  0.0              2.0    130.0              204.0              0.0
# ..    ...  ...              ...      ...                ...              ...
# 298  45.0  1.0              1.0    110.0              264.0              0.0
# 299  68.0  1.0              4.0    144.0              193.0              1.0
# 300  57.0  1.0              4.0    130.0              131.0              0.0
# 301  57.0  0.0              2.0    130.0              236.0              0.0
# 302  38.0  1.0              3.0    138.0              175.0              0.0
#
# ...

# %%
#Printing the columns in df
(df.columns)
# Out:
# Index(['age', 'sex', 'chest_pain_type', 'rest_bp', 'serum_cholesterol',
#        'fastblood_sugar', 'rest_ecg', 'max_heartrate', 'exercise_angina',
#        'ST_depression_exercise_relativeto_rest', 'slope_peak_STsegment',
#        'num_major_vessels_fluroscopy', 'thal', 'heart_disease_status'],
#       dtype='object')

# %%
df.dtypes
# Out:
# age                                       float64
# sex                                       float64
# chest_pain_type                           float64
# rest_bp                                   float64
# serum_cholesterol                         float64
# fastblood_sugar                           float64
# rest_ecg                                  float64
# max_heartrate                             float64
# exercise_angina                           float64
# ST_depression_exercise_relativeto_rest    float64
# slope_peak_STsegment                      float64
# num_major_vessels_fluroscopy               object
# thal                                       object
# heart_disease_status                        int64
# dtype: object

# %%
#Let us try to check the description of the data
data_description = open('cleveland_heart_attr_description.txt','r').read()
print (data_description)
# Out:
# Publication Request:
#    >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
#    This file describes the contents of the heart-disease directory.
#
#    This directory contains 1 database concerning heart disease diagnosis.
#    All attributes are numeric-valued.  The data was collected from the
#     following location:
#
#      1. Cleveland Clinic Foundation (cleveland.data)
#
# While the database contains 76 attributes, only  14 attributes were actually used in past experiments.
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
#
# 1. Title: Heart Disease Databases
#
# 2. Source Information:
#    (a) Creators:
#        -- 1. Hungarian Institute of Cardiology. Budapest: Andras Janosi, M.D.
#    (b) Donor: David W. Aha (aha@ics.uci.edu) (714) 856-8779
#    (c) Date: July, 1988
#
#
# 3. Relevant Information:
#      This database contains 76 attributes, but all published experiments
# ...

# %% [markdown]
# 2.Why are the num major vessels fluroscopy and thal columns considered object types? Write the
# reason

# %% [markdown]
# = Because (1) there are some "?" at some values like in last value of the column num_major_vessels_fluroscopy contain "?"
# (2) and in 'thal' column 277 number row contain with "?"

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   age                                     303 non-null    float64
#  1   sex                                     303 non-null    float64
#  2   chest_pain_type                         303 non-null    float64
#  3   rest_bp                                 303 non-null    float64
#  4   serum_cholesterol                       303 non-null    float64
#  5   fastblood_sugar                         303 non-null    float64
#  6   rest_ecg                                303 non-null    float64
#  7   max_heartrate                           303 non-null    float64
#  8   exercise_angina                         303 non-null    float64
#  9   ST_depression_exercise_relativeto_rest  303 non-null    float64
# ...

# %%
#If an explicit description about data is missing, we can try to understand the data using basic statistical information
df.describe()
# Out:
#               age         sex  chest_pain_type     rest_bp  serum_cholesterol  \
# count  303.000000  303.000000       303.000000  303.000000         303.000000
# mean    54.438944    0.679868         3.158416  131.689769         246.693069
# std      9.038662    0.467299         0.960126   17.599748          51.776918
# min     29.000000    0.000000         1.000000   94.000000         126.000000
# 25%     48.000000    0.000000         3.000000  120.000000         211.000000
# 50%     56.000000    1.000000         3.000000  130.000000         241.000000
# 75%     61.000000    1.000000         4.000000  140.000000         275.000000
# max     77.000000    1.000000         4.000000  200.000000         564.000000
#
#        fastblood_sugar    rest_ecg  max_heartrate  exercise_angina  \
# count       303.000000  303.000000     303.000000       303.000000
# mean          0.148515    0.990099     149.607261         0.326733
# ...

# %%
#for categorical variables we can use the following
df.describe(include=object)
#Try to see if the results make sense.
#Think about other ways to make the results include actual categorical attributes.
# Out:
#        num_major_vessels_fluroscopy thal
# count                           303  303
# unique                            5    4
# top                             0.0  3.0
# freq                            176  166

# %%
#To get other information about the data, we can use info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   age                                     303 non-null    float64
#  1   sex                                     303 non-null    float64
#  2   chest_pain_type                         303 non-null    float64
#  3   rest_bp                                 303 non-null    float64
#  4   serum_cholesterol                       303 non-null    float64
#  5   fastblood_sugar                         303 non-null    float64
#  6   rest_ecg                                303 non-null    float64
#  7   max_heartrate                           303 non-null    float64
#  8   exercise_angina                         303 non-null    float64
#  9   ST_depression_exercise_relativeto_rest  303 non-null    float64
# ...

# %% [markdown]
# 3. From the histogram on age attribute, identify the number of bins and bin size. Report these quantities.

# %%
df.hist(column='age')
#[R] From the histogram identify the number of bins and bin size. Report these quantities.
# Out:
# array([[<Axes: title={'center': 'age'}>]], dtype=object)

# %% [markdown]
# In this Histogram, by default we get the number of bins is 10 . We can change the number of bins and the bin size by using "(max-min)/10" ,where we use max and min value from the 'age' column.

# %% [markdown]
# 4. Plot the histogram for 50 bins and report the bin size and your observations.

# %%
df.hist(column='age',bins=50)
# Out:
# array([[<Axes: title={'center': 'age'}>]], dtype=object)

# %%
bin_size=(58-29)/50
bin_size
# Out:
# 0.58

# %% [markdown]
# Obsv : Here we got the bin size 0.58 because we increase the number of bins so the bin size reduces.

# %%
import seaborn as sns

# %%
#The age distribution can be plotted as a graph based on the underlying histogram
sns.histplot(df.age,kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
#Replotting the distribution for 50 bins
sns.histplot(df.age,bins=50,kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %% [markdown]
# 5. What is the KDE option useful for in histplot()? Explain the details

# %% [markdown]
# = Kernel density estimation(KDE) is another widely used technique for estimating the distribution of data. In a histogram, each value in the dataset is represented using rectangular bars/blocks, and the blocks are piled on top each other into the bins to show the number of values in each bin range.

# %%
6.
#[R] Plot pandas based histogram and seaborn based histogram for serum_cholesterol attribute. Use bin sizes from {default, 20, 50, 100, 200, 500}. For seaborn, use KDE. Report the observations.

df.hist(column='serum_cholesterol')
sns.histplot(df.serum_cholesterol,kde=True)
for i in (20, 50, 100, 200, 500):
  df.hist(column='serum_cholesterol',bins =i)
  sns.histplot(df.serum_cholesterol,bins= i,kde=True)

# %% [markdown]
# 6.Obsv :

# %%
for i in (10,20, 50, 100, 200, 500):
  sns.histplot(df.serum_cholesterol, bins=i, kde=True)
plt.show()

# %% [markdown]
# We can observe all are different different according to their bin sizes.using kde we can see how the data behaves, that is almost same in every bins .

# %% [markdown]
# 7.Add to the above plot containing mean and median, the vertical lines to represent the 25 percentile and 75 percentile values in the serum_cholesterol attribute. Use different colors and appropriate legend.

# %%
import matplotlib.pyplot as plt
import numpy as np
sns.histplot(df.serum_cholesterol, bins=100)
plt.axvline(x=np.mean(df.serum_cholesterol),color='yellow',label='mean')
plt.axvline(x=np.median(df.serum_cholesterol),color='black',label='median')
plt.axvline(x=np.percentile(df.serum_cholesterol,25),color='red',label='25th percentile')
plt.axvline(x=np.percentile(df.serum_cholesterol,75),color='magenta',label='75th percentile')
plt.legend(loc='upper right')

# %%
df['gender'] = np.where(df['sex']==1.0,'male','female')
gender_counts = pd.crosstab(index=df.gender, columns='count')

# %%
sns.catplot(x="gender",data=df,kind='count')

# %%
sns.catplot(x="chest_pain_type",data=df,kind='count')

# %%
#Let us plot the bar plot for gender vs serum_cholesterol
sns.barplot(x="gender",y="serum_cholesterol",data=df)
#What does the plot describe? What are the vertical bars in each bar?
# Out:
# <Axes: xlabel='gender', ylabel='serum_cholesterol'>

# %% [markdown]
# 8.Change the order in the bar plots for gender vs serum cholesterol from male, female to female, male
# and replot

# %%
sns.barplot(x="gender",y="serum_cholesterol",data=df,order=['female','male'])
# Out:
# <Axes: xlabel='gender', ylabel='serum_cholesterol'>

# %% [markdown]
# 9. Explain the difference between the bar plot obtained using the median estimator for gender vs
# serum cholesterol and the bar plot obtained before

# %%
sns.barplot(x="gender",y="serum_cholesterol",data=df,estimator=np.median)
# Out:
# <Axes: xlabel='gender', ylabel='serum_cholesterol'>

# %%
a=sns.barplot(x="gender",y="serum_cholesterol",data=df,order=['female','male'])
a.bar_label(a.containers[0], fmt='%.1f')
# Out:
# [Text(0, 0, '261.8'), Text(0, 0, '239.6')]

# %%
x=sns.barplot(x="gender",y="serum_cholesterol",data=df,estimator=np.median)
x.bar_label(x.containers[0], fmt='%.1f')
# Out:
# [Text(0, 0, '235.0'), Text(0, 0, '254.0')]

# %% [markdown]
# Observation :
# Mean Estimator: In this code, seaborn barplot is used and it represents the central tendency of the numerical variable in each category using mean value.\
# Median Estimator:In this case, the height of each bar will be determined by the median value of the numeric variable for that category.\
# The value (of having colesterol) is higher in female than Male.

# %% [markdown]
# 10.Explain the observations from the bar plot containing gender vs serum cholesterol grouped according to chest pain type.

# %%
#We can create bar plots with even more fine-grained grouping
#Let us group according to chest_pain_type
sns.barplot(x="gender",y="serum_cholesterol",hue="chest_pain_type",data=df)
#[R} Explain the observations from the plot.
# Out:
# <Axes: xlabel='gender', ylabel='serum_cholesterol'>

# %%
#We can adjust the positioning of the legend.
ax = sns.barplot(x="gender",y="serum_cholesterol",hue="chest_pain_type",data=df)
ax.legend(loc='upper left', ncol=4)

# %%
#We can adjust the positioning of the legend.
ax = sns.barplot(x="gender",y="serum_cholesterol",hue="chest_pain_type",data=df)
ax.legend(loc='upper left', ncol=4)
ax.set_xlabel("Gender",fontsize=15)
ax.set_ylabel("Serum Cholesterol",fontsize=15)
# Out:
# Text(0, 0.5, 'Serum Cholesterol')

# %%
#We can also adjust the display effects of the labels on axes
ax = sns.barplot(x="gender",y="serum_cholesterol",hue="chest_pain_type",data=df)
ax.legend(loc='upper left', ncol=4)
ax.set_xlabel("Gender",fontsize=15,rotation=50)
ax.set_ylabel("Serum Cholesterol",fontsize=15)
ax.set_xticklabels(ax.get_xticklabels(),fontsize=13,rotation=40)
# Out:
# [Text(0, 0, 'male'), Text(1, 0, 'female')]

# %% [markdown]
# In this barplot we can see how serum cholesterol levels vary across different chest pain types for each gender. The height of each bar in the barplot represents the average or median serum cholesterol levels for a specific combination of gender, chest pain type.Each group corresponds to a specific chest pain type reported by individuals.We can compare how serum cholesterol levels vary between males and females within each chest pain type group.In average cases, women have the higher chance than male.

# %% [markdown]
# 11.

# %%
#[R] Note that the chest_pain_type is numerical and hence is of less value in the plot above.
# To make the plot more meaningful, insert a new column to the dataframe which contains the description according to the corresponding chest_pain_type code.
# Name this column as chest_pain_type_description.
# To fill the values in this chest_pain_type_description column, take the description for chest_pain_type from description file.
# Construct the above grouped bar plot where the grouping is now with respect to the textual description of the chest_pain_type.
# Add an appropriate legend and display the legend in a position where the bar graphs are clearly visible.

# %%
df['chest_pain_type_description']=df['chest_pain_type'].replace([1,2,3,4],['typical angina','atypical angina','non-anginal pain','asymptomatic'])
df.head(5)
ax = sns.barplot(x="gender",y="serum_cholesterol",hue="chest_pain_type_description",data=df)

# %%
#We can work with the different components of the bar plot if we want to process them individually
#We will consider the bar plot based on gender vs serum_cholesterol
plot = sns.barplot(x="gender",y="serum_cholesterol",data=df)

#plot has error lines which can be obtained from plot.lines
for line in plot.lines:
  print(line.get_ydata())
  print(line.get_xdata())
  print(line.get_xydata())
# Out:
# [234.10618932 245.4243932 ]
# [0 0]
# [[  0.         234.10618932]
#  [  0.         245.4243932 ]]
# [250.09097938 275.89793814]
# [1 1]
# [[  1.         250.09097938]
#  [  1.         275.89793814]]

# %%
#we can also use annotations for bar plots
#We will consider the bar plot based on gender vs serum_cholesterol
plot = sns.barplot(x="gender",y="serum_cholesterol",data=df)


for p,line in zip(plot.patches, plot.lines):
    plot.annotate(format(p.get_height(),'.1f'),
                   (p.get_x() + p.get_width() / 2., line.get_ydata()[1]),
                   ha = 'center', va = 'top',
                   xytext = (0, 9),
                   textcoords = 'offset points')
#Try to find the meaning of the different arguments used in annotate function

# %%
cholesterol level is high in female than male.

# %% [markdown]
# 12.

# %%
#[R] Add an appropriate annotation indicating the value of the upper boundary values of the bar plots in the gender vs serum_cholesterol bar plot grouped according to chest_pain_type attribute.

# %%
plot = sns.barplot(x="gender",y="serum_cholesterol",hue='chest_pain_type_description',data=df)
for p,line in zip(plot.patches, plot.lines):
    plot.annotate(format(p.get_height(),'.1f'),
                   (p.get_x() + p.get_width() / 2., line.get_ydata()[1]),
                   ha = 'center', va = 'top',
                   xytext = (0, 9),
                   textcoords = 'offset points')

# %% [markdown]
# 13.

# %%
#[R] Add an appropriate annotation with pointed arrows and with textual description in bar plot of gender vs serum_cholesterol bar plot grouped according to chest_pain_type attribute.
# Color the arrow with a color other than red.

# %%
import matplotlib.pyplot as plt
#There are other ways to add annotations to bar plots
#We will consider the bar plot based on gender vs serum_cholesterol
plot = sns.barplot(x="gender",y="serum_cholesterol",hue='chest_pain_type_description',data=df)

#plot.patches[0].get_x()

x=plot.patches[0].get_x() + plot.patches[0].get_width() / 2.
y=plot.lines[0].get_ydata()[1]
plt.annotate('The average serum cholesterol\n for men is lower in which chest_type is  !', xy=(x,y), xytext=(x+.3,y+100), arrowprops=dict(facecolor='magenta'))
x=plot.patches[1].get_x() + plot.patches[0].get_width() / 2.
y=plot.lines[0].get_ydata()[1]

plt.annotate('The average serum cholesterol\n for women is lower in which chest_type is  !', xy=(x,y), xytext=(x+.3,y+60), arrowprops=dict(facecolor='black'))
# Out:
# Text(1.0, 310.9486842105263, 'The average serum cholesterol\n for women is lower in which chest_type is  !')

# %% [markdown]
# 14.

# %%
#To capture whether two attributes are correlated, one way is to use scatter plot
#Let us try to see if age is related to serum_cholesterol

sns.scatterplot(x="age",y="serum_cholesterol",data=df)
#[R] Explain your observations from the scatter plot.
# Out:
# <Axes: xlabel='age', ylabel='serum_cholesterol'>

# %% [markdown]
# Observation:
# Age 40 - 50 :cholesterol level is in between 200-300.\
# Age is increasing (at age 60 , 70),it indicates increase in cholesterol level .\
# At age below 40 the cholesterol level is between 200 .By scatter plot we can find out relations and most of the areas(cluster) where data points lies.

# %%
#Let us plot the relation between chest_pain_type and serum_cholesterol

sns.scatterplot(x="chest_pain_type",y="serum_cholesterol",data=df)
# Out:
# <Axes: xlabel='chest_pain_type', ylabel='serum_cholesterol'>

# %% [markdown]
# 15.

# %%
#We can also use lineplot to plot the relationship between variables
sns.lineplot(x="age",y="serum_cholesterol",data=df)
# Out:
# <Axes: xlabel='age', ylabel='serum_cholesterol'>

# %% [markdown]
# The dark central line in the plot represents the central tendency of the data. represents the mean, median, or some other measure of central location for the serum cholesterol values at each age. This line helps we understand the average  serum cholesterol level at different age .
# The light-colored line indicates the 95%confidence interval of the mean, they show how much the data points tend to vary from the central tendency at each age point.

# %% [markdown]
# 16.

# %%
#We can use blox plots which would provide details about summary statistics
sns.boxplot(x="chest_pain_type",y="serum_cholesterol",data=df)
# Out:
# <Axes: xlabel='chest_pain_type', ylabel='serum_cholesterol'>

# %%
#[R] What do the upper and lower boundaries of the box indicate? What does the line inside the box indicate? What are the points marked beyond the error bars?  Explain.

# %% [markdown]
# The upper boundary of the box typically represents the third quartile (Q3) of the data. In other words, it's the value below which 75% of the data points lie. The lower boundary of the box represents the first quartile of the data, which is the value below which 25% of the data points lie.\
# The line inside the box represents the median of the data, which is the middle value when the data is sorted in ascending order. It divides the data into two equal halves, with 50% of the data points falling above it and 50% below it.\
# Outliers are data points that are different from the rest of the data. They are individual data points that are unusually high or low when compared to the rest of the dataset. Outliers are important to identify because they may indicate data quality ,we get unique observations from it.

# %% [markdown]
# 17.

# %%
#We can also group the above box plots according to gender
#recall "hue" in barplot
sns.boxplot(x="chest_pain_type",y="serum_cholesterol",hue="gender",data=df)
# Out:
# <Axes: xlabel='chest_pain_type', ylabel='serum_cholesterol'>

# %% [markdown]
# We can observe how serum cholesterol levels are distributed among males and females separately by the median, quartiles to understand the central tendency and variability in cholesterol levels for each gender. each gender group, We can compare serum cholesterol levels for different chest pain types.\
# We check for outliers inbox plot. Outliers could indicate individuals with unusually high or low serum cholesterol levels within specific gender and chest pain type categories.

# %%
#[R] Use violinplot to plot the relationship between chest_pain_type and serum_cholesterol and discuss the observations.
sns.violinplot(x="chest_pain_type",y="serum_cholesterol",data=df)
# Out:
# <Axes: xlabel='chest_pain_type', ylabel='serum_cholesterol'>

# %% [markdown]
# For each chest pain type (e.g., typical angina, atypical angina, non-anginal pain, asymptomatic), the violin plot shows the distribution of serum cholesterol levels. The shape of each "violin" gives We insights into the data distribution.
# If a violin is wider in certain areas, it indicates a higher density of data points in that region. If it's narrower, the data is less dense.

# %%
#[R] Can you group the violinplots based on gender information? If so, prepare the corresponding plots and discuss the observations.
sns.violinplot(x="chest_pain_type",y="serum_cholesterol",hue="gender",data=df)
# Out:
# <Axes: xlabel='chest_pain_type', ylabel='serum_cholesterol'>

# %% [markdown]
# We can now see how the distribution of serum cholesterol differs for males and females within each chest pain type. Each "violin" is split into two parts: one for males and one for females.
# Compare the shapes of these split violins for each chest pain type to understand how cholesterol levels vary between genders.For female the size of the plot changes drastically in each type than male.
